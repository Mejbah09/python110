# %%
def generate_course(x):
  j=x.split(' ')
  y=''
  tpl=tuple(j)
  k,b=tpl
  m=''
  for i in k:
    if ord("A")<ord(i)<ord('Z') or ord("a")<ord(i)<ord('z'):
      pass
    else:
      m+=i

  for i in range(len(m)):
     if(int(m[-1]))%2==0:
       return 'Invalid Course','Invalid Code'
     else:
      course_code=(int(m[-1]))+1
      if i%2!=0:
        c=ord(i)+1
        ch=chr(c)
      return course_code ,c
v=generate_course('CSE331 Automata')
l,j=v
print('New Course')
print(f'Title : {j}' )
print(f'code : {l}' )
